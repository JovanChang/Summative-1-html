# %%
import pandas as pd

df = pd.read_csv("artworks.csv")

df
# Out:
#         Artwork ID                                              Title  \
# 0                2  Ferdinandsbrücke Project, Vienna, Austria, Ele...
# 1                3  City of Music, National Superior Conservatory ...
# 2                4  Villa near Vienna Project, Outside Vienna, Aus...
# 3                5  The Manhattan Transcripts Project, New York, N...
# 4                6  Villa, project, outside Vienna, Austria, Exter...
# ...            ...                                                ...
# 130257      217983                                        Seul/NY/MAX
# 130258      217984   Fluxus-Manifestatie in en Rond Kunsthandel Monet
# 130259      217985                             Fluxphone Compositions
# 130260      217986                                       Unidentified
# 130261      218011                           Portrait of Takako Saito
#
#        Artist ID                      Name  Date  \
# 0           6210               Otto Wagner  1896
# ...

# %%
df.loc[:,["Classification"]]
# Out:
#        Classification
# 0        Architecture
# 1        Architecture
# 2        Architecture
# 3        Architecture
# 4        Architecture
# ...               ...
# 130257          Media
# 130258          Media
# 130259          Media
# 130260          Media
# 130261     Photograph
#
# [130262 rows x 1 columns]

# %%
df3 = df["Classification"].value_counts()

print(df3)
# Out:
# Print                             30807
# Photograph                        29909
# Illustrated Book                  26160
# Drawing                           11735
# Design                            11223
# Mies van der Rohe Archive          3331
# Architecture                       2947
# Video                              2363
# Film                               2292
# Painting                           2270
# Sculpture                          1669
# Multiple                           1030
# (not assigned)                     1029
# Frank Lloyd Wright Archive          785
# Periodical                          741
# Installation                        596
# Work on Paper                       436
# Audio                               429
# Media                               343
# Ephemera                             89
# Textile                              33
# Performance                          24
# Collage                               9
# ...

# %%
df3 = df3.drop("(not assigned)") #I do not want to include not assigned as it only confuse users
# Out:
# Print                             30807
# Photograph                        29909
# Illustrated Book                  26160
# Drawing                           11735
# Design                            11223
# Mies van der Rohe Archive          3331
# Architecture                       2947
# Video                              2363
# Film                               2292
# Painting                           2270
# Sculpture                          1669
# Multiple                           1030
# Frank Lloyd Wright Archive          785
# Periodical                          741
# Installation                        596
# Work on Paper                       436
# Audio                               429
# Media                               343
# Ephemera                             89
# Textile                              33
# Performance                          24
# Collage                               9
# Photography Research/Reference        4
# ...

# %%
headers = ["Classification","Value"]

df3.columns = headers
# Out:
# <bound method NDFrame.head of Print                             30807
# Photograph                        29909
# Illustrated Book                  26160
# Drawing                           11735
# Design                            11223
# Mies van der Rohe Archive          3331
# Architecture                       2947
# Video                              2363
# Film                               2292
# Painting                           2270
# Sculpture                          1669
# Multiple                           1030
# (not assigned)                     1029
# Frank Lloyd Wright Archive          785
# Periodical                          741
# Installation                        596
# Work on Paper                       436
# Audio                               429
# Media                               343
# Ephemera                             89
# Textile                              33
# Performance                          24
# Collage                               9
# ...

# %%
df3.to_csv("artworks_class.csv")
